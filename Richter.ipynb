# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('train_values.csv')
x = pd.read_csv('train_labels.csv')
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type           ...             \
# 0                      t               r           ...
# 1                      o               r           ...
# ...

# %%
data = pd.merge(df,x, on=['building_id'])
data.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type      ...       \
# 0                      t               r      ...
# 1                      o               r      ...
# ...

# %% [markdown]
# ##### Data Cleaning

# %% [markdown]
# ##### Converting categorical variables to numeric

# %%
####
# Has the list of all categorical variables in our dataset
list_categorical =['land_surface_condition','foundation_type','roof_type','ground_floor_type','other_floor_type','position','plan_configuration','legal_ownership_status']
#Creates dummies or numeric (binary) variables for each value a categorical variable takes
data = pd.get_dummies(data,columns=list_categorical)

# %%
# Out:
# 0    3
# 1    2
# 2    3
# 3    2
# 4    3
# Name: damage_grade, dtype: int64
